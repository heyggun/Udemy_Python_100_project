# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## `622강`
# 74일차 목표 - 오늘 하루 작업할 것

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## `623강`
# 데이터 탐색 - 구글 검색 데이터 이해하기

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
os.listdir('data/')
# Out:
# ['Bitcoin Search Trend.csv',
#  'Daily Bitcoin Price.csv',
#  'TESLA Search Trend vs Price.csv',
#  'UE Benefits Search vs UE Rate 2004-19.csv',
#  'UE Benefits Search vs UE Rate 2004-20.csv']

# %% [markdown]
# *테슬라 데이터*

# %%
df_tesla = pd.read_csv('data/TESLA Search Trend vs Price.csv')
df_tesla
# Out:
#           MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0    2010-06-01                3        4.766000
# 1    2010-07-01                3        3.988000
# 2    2010-08-01                2        3.896000
# 3    2010-09-01                2        4.082000
# 4    2010-10-01                2        4.368000
# ..          ...              ...             ...
# 119  2020-05-01               16      167.000000
# 120  2020-06-01               17      215.962006
# 121  2020-07-01               24      286.152008
# 122  2020-08-01               23      498.320007
# 123  2020-09-01               31      407.339996
#
# [124 rows x 3 columns]

# %%
df_tesla.shape
# Out:
# (124, 3)

# %%
df_tesla.columns
# Out:
# Index(['MONTH', 'TSLA_WEB_SEARCH', 'TSLA_USD_CLOSE'], dtype='object')

# %%
df_tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
df_tesla.dtypes
# Out:
# MONTH               object
# TSLA_WEB_SEARCH      int64
# TSLA_USD_CLOSE     float64
# dtype: object

# %% [markdown]
# *실업 데이터*

# %%
df_unemployment = pd.read_csv('data/UE Benefits Search vs UE Rate 2004-19.csv')
df_unemployment
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0    2004-01                      34     5.7
# 1    2004-02                      33     5.6
# 2    2004-03                      25     5.8
# 3    2004-04                      29     5.6
# 4    2004-05                      23     5.6
# ..       ...                     ...     ...
# 176  2018-09                      14     3.7
# 177  2018-10                      15     3.8
# 178  2018-11                      16     3.7
# 179  2018-12                      17     3.9
# 180  2019-01                      21     4.0
#
# [181 rows x 3 columns]

# %%
df_unemployment.shape
# Out:
# (181, 3)

# %%
df_unemployment['UE_BENEFITS_WEB_SEARCH'].max()
# Out:
# 100

# %%
df_bit = pd.read_csv('data/Bitcoin Search Trend.csv')
df_bit
# Out:
#       MONTH  BTC_NEWS_SEARCH
# 0   2014-09                5
# 1   2014-10                4
# 2   2014-11                4
# 3   2014-12                4
# 4   2015-01                5
# ..      ...              ...
# 68  2020-05               22
# 69  2020-06               13
# 70  2020-07               14
# 71  2020-08               16
# 72  2020-09               13
#
# [73 rows x 2 columns]

# %% [markdown]
# *비트코인의 일별 종가와 거래량*

# %%
df_btc = pd.read_csv('data/Daily Bitcoin Price.csv')
df_btc
# Out:
#             DATE         CLOSE        VOLUME
# 0     2014-09-17    457.334015  2.105680e+07
# 1     2014-09-18    424.440002  3.448320e+07
# 2     2014-09-19    394.795990  3.791970e+07
# 3     2014-09-20    408.903992  3.686360e+07
# 4     2014-09-21    398.821014  2.658010e+07
# ...          ...           ...           ...
# 2199  2020-09-24  10745.548828  2.301754e+10
# 2200  2020-09-25  10702.290039  2.123255e+10
# 2201  2020-09-26  10754.437500  1.810501e+10
# 2202  2020-09-27  10774.426758  1.801688e+10
# 2203  2020-09-28  10912.536133  2.122653e+10
#
# [2204 rows x 3 columns]

# %%
df_btc.shape
# Out:
# (2204, 3)

# %% [markdown]
# *비트코인 검색량*

# %%
df_btc_search = pd.read_csv('data/Bitcoin Search Trend.csv')
df_btc_search
# Out:
#       MONTH  BTC_NEWS_SEARCH
# 0   2014-09                5
# 1   2014-10                4
# 2   2014-11                4
# 3   2014-12                4
# 4   2015-01                5
# ..      ...              ...
# 68  2020-05               22
# 69  2020-06               13
# 70  2020-07               14
# 71  2020-08               16
# 72  2020-09               13
#
# [73 rows x 2 columns]

# %%
df_btc_search['BTC_NEWS_SEARCH'].max()
# Out:
# 100

# %% [markdown]
#     데이터프레임에서 구글의 검색 관심도 범위는 0에서 100사이임
#     구글이 검색 관심도 값을 정의하는 법은
# ![image.png](attachment:image.png)
#
#     실제 검색량은 공개된 정보가 아니여서, 구글은 조정된 수치만을 제공함
#     각각의 데이터 수치는 상대적 인기도를 비교하기 위해 해당 검색 지역 및 시간 범위 별로 나눠짐
#
#     검색어 각각에 대해 구글은 각 지역과 기간별 총 검색량과 유저가 검색한 검색어 간의 관련성을 찾아줌
#     그 다음 모든 측정값을 단일 인기도 측정값으로 결합해주고, 주체 전체에 걸쳐 값을 조정함
#     즉, 구글 트렌드는 해당 주제와 관련된 검색이 몇 건 되었는지 정확한 수를 알려주기보다 보기 좋게 가공한 결과를 제시함

# %% [markdown]
# ## `624강`
# 데이터 정리 - 시계열 데이터를 다시 샘플링 하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_tesla.isnull().sum()
# Out:
# MONTH              0
# TSLA_WEB_SEARCH    0
# TSLA_USD_CLOSE     0
# dtype: int64

# %%
df_unemployment.isnull().sum()
# Out:
# MONTH                     0
# UE_BENEFITS_WEB_SEARCH    0
# UNRATE                    0
# dtype: int64

# %%
df_btc.isnull().sum()
# Out:
# DATE      0
# CLOSE     1
# VOLUME    1
# dtype: int64

# %%
df_btc[df_btc['CLOSE'].isna()]
# Out:
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
df_btc[df_btc['VOLUME'].isna()]
# Out:
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
df_btc_search.isnull().sum()
# Out:
# MONTH              0
# BTC_NEWS_SEARCH    0
# dtype: int64

# %%
print(f'Missing values for Tesla?: {df_tesla.isna().values.any()}')
print(f'Missing values for U/E?: {df_unemployment.isna().values.any()}')
print(f'Missing values for BTC price?: {df_btc.isna().values.any()}')
print(f'Missing values for BTC Search?: {df_btc_search.isna().values.any()}')
# Out:
# Missing values for Tesla?: False
# Missing values for U/E?: False
# Missing values for BTC price?: True
# Missing values for BTC Search?: False

# %%
df_btc.dropna(inplace=True)
df_btc
# Out:
#             DATE         CLOSE        VOLUME
# 0     2014-09-17    457.334015  2.105680e+07
# 1     2014-09-18    424.440002  3.448320e+07
# 2     2014-09-19    394.795990  3.791970e+07
# 3     2014-09-20    408.903992  3.686360e+07
# 4     2014-09-21    398.821014  2.658010e+07
# ...          ...           ...           ...
# 2199  2020-09-24  10745.548828  2.301754e+10
# 2200  2020-09-25  10702.290039  2.123255e+10
# 2201  2020-09-26  10754.437500  1.810501e+10
# 2202  2020-09-27  10774.426758  1.801688e+10
# 2203  2020-09-28  10912.536133  2.122653e+10
#
# [2203 rows x 3 columns]

# %%
df_btc.isnull().sum()
# Out:
# DATE      0
# CLOSE     0
# VOLUME    0
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(type(df_tesla['MONTH'].loc[0]))
print(type(df_unemployment['MONTH'].loc[0]))
print(type(df_btc['DATE'].loc[0]))
print(type(df_btc_search['MONTH'].loc[0]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
df_tesla['MONTH'] = pd.to_datetime(df_tesla['MONTH'])
df_unemployment['MONTH'] = pd.to_datetime(df_unemployment['MONTH'])
df_btc['DATE'] = pd.to_datetime(df_btc['DATE'])
df_btc_search['MONTH'] = pd.to_datetime(df_btc_search['MONTH'])

# %%
print(type(df_tesla['MONTH'].loc[0]))
print(type(df_unemployment['MONTH'].loc[0]))
print(type(df_btc['DATE'].loc[0]))
print(type(df_btc_search['MONTH'].loc[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df_tesla['MONTH'].head()
# Out:
# 0   2010-06-01
# 1   2010-07-01
# 2   2010-08-01
# 3   2010-09-01
# 4   2010-10-01
# Name: MONTH, dtype: datetime64[ns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_btc.head(3)
# Out:
#         DATE       CLOSE      VOLUME
# 0 2014-09-17  457.334015  21056800.0
# 1 2014-09-18  424.440002  34483200.0
# 2 2014-09-19  394.795990  37919700.0

# %% [markdown]
#     해당 월말의 가격

# %%
df_btc_monthly = df_btc.resample('M', on='DATE').last()
df_btc_monthly
# Out:
#                  DATE         CLOSE        VOLUME
# DATE
# 2014-09-30 2014-09-30    386.944000  3.470730e+07
# 2014-10-31 2014-10-31    338.321014  1.254540e+07
# 2014-11-30 2014-11-30    378.046997  9.194440e+06
# 2014-12-31 2014-12-31    320.192993  1.394290e+07
# 2015-01-31 2015-01-31    217.464005  2.334820e+07
# ...               ...           ...           ...
# 2020-05-31 2020-05-31   9461.058594  2.777329e+10
# 2020-06-30 2020-06-30   9137.993164  1.573580e+10
# 2020-07-31 2020-07-31  11323.466797  2.316047e+10
# 2020-08-31 2020-08-31  11680.820313  2.228593e+10
# 2020-09-30 2020-09-28  10912.536133  2.122653e+10
#
# [73 rows x 3 columns]

# %% [markdown]
#      한 달 동안의 평균 가격

# %%
df_btc_montly = df_btc.resample('M', on='DATE').mean()
df_btc_montly
# Out:
#                    CLOSE        VOLUME
# DATE
# 2014-09-30    407.182428  2.934864e+07
# 2014-10-31    364.148873  2.912885e+07
# 2014-11-30    366.099799  2.199111e+07
# 2014-12-31    341.267871  1.784201e+07
# 2015-01-31    248.782547  3.544555e+07
# ...                  ...           ...
# 2020-05-31   9263.151745  4.149575e+10
# 2020-06-30   9489.227214  2.169711e+10
# 2020-07-31   9589.899729  1.760688e+10
# 2020-08-31  11667.277572  2.290423e+10
# 2020-09-30  10655.702218  3.039781e+10
#
# [73 rows x 2 columns]

# %% [markdown]
# ## `625강`
# 데이터 시각화 - 맷플롯립을 이용한 테슬라 선형 차트

# %% [markdown]
#     - 테슬라 주가와 검색 인기도에 대한 기본 꺾은선 차트 -> 차트에 스타일 추가
#
# ![image.png](attachment:image.png)

# %%
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('TSLA Stock Price')
ax2.set_ylabel('Search Trend')

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'])
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH']);

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('TSLA Stock Price', color='#E6232E')
ax2.set_ylabel('Search Trend', color='lightskyblue')

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color = '#E6232E')
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], color = 'lightskyblue');

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
plt.figure(figsize=(14,8))
plt.title('Tesla Web Search vs Price')

plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()


ax1.set_ylabel('TSLA Stock Price', color= '#E6232E', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color= '#E6232E')
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], color='skyblue');

# %% [markdown]
# *matplotlib 경고 메시지 처리*
# ![image.png](attachment:image.png)

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ## `626강`
# 로케이터와 데이트포매터를 사용하여 타임라인에 눈금 표시

# %% [markdown]
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %%
import matplotlib.dates as mdates

# %%
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# %%
plt.figure(figsize=(14,8))
plt.title('Tesla Web Search vs Price')

plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()


ax1.set_ylabel('TSLA Stock Price', color= '#E6232E', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color= '#E6232E')
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], color='skyblue');

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# %% [markdown]
# ## `627강`
# 데이터 시각화 - 비트코인: 선 스타일과 마커

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(14,8), dpi=120)
 
plt.title('Bitcoin News Search vs Resampled Price', fontsize=18)
plt.xticks(fontsize=14, rotation=45)
 
ax1 = plt.gca()
ax2 = ax1.twinx()
 
ax1.set_ylabel('BTC Price', color='#F08F2E', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)
 
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)
 
ax1.set_ylim(bottom=0, top=15000)
ax1.set_xlim([df_btc_monthly.index.min(), df_btc_monthly.index.max()])
 
# Experiment with the linestyle and markers
ax1.plot(df_btc_monthly.index, df_btc_monthly.CLOSE, 
         color='#F08F2E', linewidth=3, linestyle='--')
ax2.plot(df_btc_monthly.index, df_btc_search.BTC_NEWS_SEARCH, 
         color='skyblue', linewidth=3, marker='o')
 
plt.show()

# %% [markdown]
#     - 테슬라 때와 마찬가지로 2018년 초에 엄청난 가격 움직임이 매우 높은 검색량과 연관이 있음
#     - 2017년 말부터 2018년 초에는 모두가 비트코인에 대해 이야기하고, 구입해서 검색량이 사상 최고치 기록
#     - 2019년 1분기에도 역시 비트코인 가격이 폭등했지만 이 시점의 검색량 증가는 크게 늘어나고 있지 않음

# %% [markdown]
# ## `628강`
# 데이터 시각화 - 실업: 격자 이용 방법

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_unemployment.head(3)
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0 2004-01-01                      34     5.7
# 1 2004-02-01                      33     5.6
# 2 2004-03-01                      25     5.8

# %%
plt.figure(figsize=(14,8), dpi=120)
 
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate', fontsize=18)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)
 
ax1 = plt.gca()
ax2 = ax1.twinx()
 
ax1.grid(color='grey', linestyle='--')

ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)
 
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployment['MONTH'].min(), df_unemployment['MONTH'].max()])

ax1.grid(color='grey', linestyle='--')
 
# Experiment with the linestyle and markers
ax1.plot(df_unemployment['MONTH'], df_unemployment['UNRATE'], 
         color='purple', linewidth=3, linestyle='--')
ax2.plot(df_unemployment['MONTH'], df_unemployment['UE_BENEFITS_WEB_SEARCH'], 
         color='skyblue', linewidth=3)
 
plt.show()

# %% [markdown]
#     - 2013년 말 실업급여에 대한 검색량이 폭등했지만 실업률이 크게 증가하지 않았음

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
roll_6_df = df_unemployment[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.title('Rolling Monthly US "Unemployment Benefits" Web Searches vs UNRATE', fontsize=18)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)
 
ax1 = plt.gca()
ax2 = ax1.twinx()
 
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)
 
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=16)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=16)
 
ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployment['MONTH'][0], df_unemployment['MONTH'].max()])
 
# Calculate the rolling average over a 6 month window
roll_6_df = df_unemployment[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()
 
ax1.plot(df_unemployment['MONTH'], roll_6_df['UNRATE'], 'purple', linewidth=3, linestyle='-.')
ax2.plot(df_unemployment['MONTH'], roll_6_df['UE_BENEFITS_WEB_SEARCH'], 'skyblue', linewidth=3)
 
plt.show()

# %% [markdown]
#     - 실업 급여에 대한 검색은 실제로 공식 실업률이 올라가기 전에 이루어진다는 것
#     - 마찬가지로, 이 용어에 대한 검색 빈도는 실업률 감소 전에 먼저 내려감
#     - 검색은 실업률에 대한 선행 경제 지표로 작용

# %% [markdown]
# ## `629강`
# 데이터 시각화 - 실업: 새로운 데이터에 의한 영향

# %% [markdown]
#     - 2008년의 금융위기가 회복되기 까지 10년 가량의 시간
#     - 2020년이 분석에 어떠한 영향을 미치는 지

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
new_data = pd.read_csv('data/UE Benefits Search vs UE Rate 2004-20.csv')
new_data
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0    2004-01                       9     5.7
# 1    2004-02                       8     5.6
# 2    2004-03                       7     5.8
# 3    2004-04                       8     5.6
# 4    2004-05                       6     5.6
# ..       ...                     ...     ...
# 195  2020-04                     100    14.7
# 196  2020-05                      63    13.3
# 197  2020-06                      53    11.1
# 198  2020-07                      54    10.2
# 199  2020-08                      50     8.4
#
# [200 rows x 3 columns]

# %%
new_data['MONTH'] = pd.to_datetime(new_data['MONTH'])
new_data
# Out:
#          MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0   2004-01-01                       9     5.7
# 1   2004-02-01                       8     5.6
# 2   2004-03-01                       7     5.8
# 3   2004-04-01                       8     5.6
# 4   2004-05-01                       6     5.6
# ..         ...                     ...     ...
# 195 2020-04-01                     100    14.7
# 196 2020-05-01                      63    13.3
# 197 2020-06-01                      53    11.1
# 198 2020-07-01                      54    10.2
# 199 2020-08-01                      50     8.4
#
# [200 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Monthly US "Unemployment Benefits" Web Search vs UNRATE incl 2020', fontsize=10)

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=16)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=16)
ax1.set_xlim([new_data['MONTH'].min(), new_data['MONTH'].max()])


ax1.plot(new_data['MONTH'], new_data['UNRATE'], 'purple', linewidth=3)
ax2.plot(new_data['MONTH'], new_data['UE_BENEFITS_WEB_SEARCH'], 'skyblue', linewidth=3);

# %% [markdown]
# ## `630강`
# 핵심 내용 및 요약

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
